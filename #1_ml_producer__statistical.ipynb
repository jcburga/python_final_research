# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Load the dataset
df = pd.read_csv(r'C:\Users\jcbur\OneDrive - peruvianbusinesscouncil.org\csv files\#11_python_final_assignment\#6_statystical_ratios\ml_producer_profile_selected_features.csv')

# Perform statistical analysis on each column
statistical_analysis = df.describe()

# Standardize the dataset
scaler = StandardScaler()
df_standardized = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# Perform statistical analysis on the standardized dataset
standardized_statistical_analysis = df_standardized.describe()

# Print the statistical analysis
print("Statistical Analysis:")
print(statistical_analysis)

# Print the statistical analysis of the standardized dataset
print("\\nStatistical Analysis of the Standardized Dataset:")
print(standardized_statistical_analysis)
# Out:
# Statistical Analysis:
#        category_region_id  producers_numerical  granted_loans_percent  \
# count           25.000000            25.000000              25.000000
# mean            12.760000           -69.036080              -3.620384
# std              7.688086           167.241737               2.823432
# min              0.000000          -862.860000              -9.403240
# 25%              7.000000           -51.420000              -5.725498
# 50%             13.000000           -31.627000              -2.964951
# 75%             19.000000           -16.276000              -1.697039
# max             25.000000            -3.061000               1.575377
#
#        requested_loans_percent  trained_percent  illiteracy_percent  \
# count                25.000000        25.000000           25.000000
# mean                 -3.834131        -6.603681           13.993023
# std                   2.903950         3.245545            7.757981
# ...
