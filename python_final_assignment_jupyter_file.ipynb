# %% [markdown]
# # data! data! data!
#
# # Agriculture in Peru
#     # Historical Data:
#
# # Agriculture in Peru (done)
#     # People Economically Active by Sectors in Peru, Women, Men, and Gender Gap (period: 2021)
#     # People in Agriculture in Peru, Women, Men, and Gender Gap (period: 2011 - 2021)
#     # Agriculture: Main Indicators
#         # Total Revenue PEN-2007
#         # Contribution of Agriculture to the National GDP
#         # Added Value of Agriculture
#         # Crops in Peru (millions of hectars)
#         # Harvesting in Peru (millions of hectars)
#         # Disasters Affecting Crops in Peru
#
# # Gender Gap in Agriculture
#     # Socio-Economic Bottomline
#         # Education: Secondary Education Completed
#         # Illiteracy
#         # Languages
#             # Spanish
#             # Quechua
#             # Aymara
#             # Amazonia
#     # Gender Gap and Access to Credit
#         # Financial Offer in Agriculture
#             # Foreign Investments
#             # Rural Banks
#             # Municipal Banks
#             # Local Private Financial Institutions
#         # Why producers don't apply to credit
#         # Associtivity
#         # Producers that received credit
#         # Producers that requested credit
#     # Gender Gap and Access to Training
#         # Producers that accessed training
#
# # Addressing the Gender Gap through Financing and Training

# %% [markdown]
# # Agriculture in Peru:
#     # Historical Data:

# %% [markdown]
# # Agriculture in Peru
#     # People Economically Active by Sector (Year 2021)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataframe
df = pd.read_csv(r'c:\Users\jcbur\OneDrive - peruvianbusinesscouncil.org\csv files\#9_peru_agriculture\agriculture_employment\employment_sector_gender.csv')

# Filter rows based on column: 'region_id'
df = df[df['region_id'] == 0]

# Filter rows based on column: 'gender'
df = df[df['gender'] != "Total"]

# Filter rows based on column: 'Sum of year'
df = df[df['Sum of year'] == 2021]

# Rename columns
df = df.rename(columns={'Sum of year': 'year', 'Sum of value_percent': 'employment'})

# Replace all instances of "Mujeres" with "Women" in column: 'gender'
df.loc[df['gender'].str.lower() == "Mujeres".lower(), 'gender'] = "Women"

# Replace all instances of "Hombres" with "Men" in column: 'gender'
df.loc[df['gender'].str.lower() == "Hombres".lower(), 'gender'] = "Men"

# Pivot the dataframe to get 'Women' and 'Men' employment percentages in separate columns
pivot_df = df.pivot(index='sector', columns='gender', values='employment')

# Calculate the gender gap by subtracting 'Men' from 'Women'
pivot_df['Gender Gap'] = pivot_df['Women'] - pivot_df['Men']

# Reset index to get 'sector' as a column
pivot_df.reset_index(inplace=True)

# Plot the chart comparing men, women, and the gender gap
plt.figure(figsize=(10, 8))
pivot_df.plot(x='sector', y=['Men', 'Women', 'Gender Gap'], kind='bar')
plt.title('Population Economically Active by Sectors for 2021: Men, Women, and Gender Gap')
plt.xlabel('Sector')
plt.ylabel('Population Percentage')
plt.xticks(rotation=45)
plt.tight_layout()
plt.legend(title='Gender')
plt.show()

# Print the rows of the pivoted dataframe to verify the pivot
print(pivot_df)
# Out:
# gender                        sector        Men      Women  Gender Gap
# 0                        Agricultura  28.868778  25.650918   -3.217860
# 1                           Comercio  13.338940  27.469153   14.130212
# 2                       Construcción  12.450684   0.559213  -11.891471
# 3                        Manufactura   9.262580   8.092969   -1.169612
# 4                    Otros servicios  20.407006  36.350482   15.943475
# 5                      Pesca/Minería   2.784192   0.243357   -2.540835
# 6       Transportes y Comunicaciones  12.887819   1.633909  -11.253910

# %% [markdown]
# # Agriculture in Peru
#     # People Economically Active in Agriculture (Years 2011 - 2021)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataframe
df = pd.read_csv(r'c:\\Users\\jcbur\\OneDrive - peruvianbusinesscouncil.org\\csv files\\#9_peru_agriculture\\agriculture_employment\\employment_sector_gender.csv')

# Filter rows based on column: 'region_id' for national level (assuming 0 represents national level)
df = df[df['region_id'] == 0]

# Filter rows based on column: 'sector'
df = df[df['sector'] == "Agricultura"]

# Filter rows based on column: 'gender'
df = df[df['gender'] != "Total"]

# Rename columns
df = df.rename(columns={'Sum of year': 'year', 'Sum of value_percent': 'employment'})

# Replace all instances of "Mujeres" with "Women" in column: 'gender'
df.loc[df['gender'].str.lower() == "Mujeres".lower(), 'gender'] = "Women"

# Replace all instances of "Hombres" with "Men" in column: 'gender'
df.loc[df['gender'].str.lower() == "Hombres".lower(), 'gender'] = "Men"

# Pivot the dataframe to get 'Women' and 'Men' employment percentages in separate columns
pivot_df = df.pivot(index='year', columns='gender', values='employment')

# Calculate the gender gap by subtracting 'Men' from 'Women'
pivot_df['Gender Gap'] = pivot_df['Women'] - pivot_df['Men']

# Reset index to get 'year' as a column
pivot_df.reset_index(inplace=True)

# Plot the chart comparing men, women, and the gender gap
plt.figure(figsize=(10, 8))
pivot_df.plot(x='year', y=['Men', 'Women', 'Gender Gap'], kind='bar')
plt.title('Population Economically Active in Agriculture 2011 - 2021: Men, Women, and Gender Gap')
plt.xlabel('Year')
plt.ylabel('Population Percentage')
plt.xticks(rotation=45)
plt.tight_layout()
plt.legend(title='Gender')
plt.show()

# Print the first few rows of the pivoted dataframe to verify the pivot
print(pivot_df)
# Out:
# gender  year        Men      Women  Gender Gap
# 0       2011  27.409328  22.415487   -4.993840
# 1       2012  26.528040  21.177682   -5.350359
# 2       2013  26.058734  21.409006   -4.649728
# 3       2014  26.389441  21.444947   -4.944493
# 4       2015  27.051340  22.304033   -4.747307
# 5       2016  26.992168  21.917092   -5.075076
# 6       2017  26.561873  20.923434   -5.638439
# 7       2018  26.851150  20.832736   -6.018414
# 8       2019  25.655778  21.145291   -4.510487
# 9       2020  33.438475  28.993502   -4.444973
# 10      2021  28.868778  25.650918   -3.217860

# %% [markdown]
# # Agriculture in Peru:
#     # Main Indicators
#         # Total Revenue
#         # Agriculture contribution to the National GDP
#         # Agriculture Added Value
#         # Crops, Land Dedicated to...
#         # Harvested Land

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv(r'c:\Users\jcbur\OneDrive - peruvianbusinesscouncil.org\csv files\#10_peru_producer_profile\final_assignment\csv_files\agricultural_indicators.csv')

# Define categories for visualization
categories = ['revenue_pen_2007', 'gdp_percent', 'added_value_PEN07', 'crops_mill_ha', 'harvested_mill_ha']

# Plotting each category
for category in categories:
    plt.figure(figsize=(10, 5))
    plt.plot(df['year'], df[category], marker='o')
    plt.title(f'{category} over the Years')
    plt.xlabel('Year')
    plt.ylabel(category)
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

print(df)
# Out:
#     index  year  gdp_percent  added_value_PEN07  crops_mill_ha  \
# 0       1  1994         6.13              11156     1385686.00
# 1       2  1995         6.06              11842     1408429.00
# 2       3  1996         6.27              12611     1492788.89
# 3       4  1997         6.15              13160     1592914.43
# 4       5  1998         6.18              13177     1605672.21
# 5       6  1999         6.77              14646     1696618.01
# 6       7  2000         6.97              15496     1670904.92
# 7       8  2001         6.88              15374     1655109.45
# 8       9  2002         6.85              16152     1655986.64
# 9      10  2003         6.71              16472     1552680.37
# 10     11  2004         6.36              16391     1684587.00
# 11     12  2005         6.19              16948     1712226.89
# 12     13  2006         6.27              18462     1740101.85
# 13     14  2007         5.97              19074     1765702.23
# 14     15  2008         5.90              20600     1798009.08
# 15     16  2009         5.89              20784     1772700.46
# 16     17  2010         5.67              21656     1733743.76
# 17     18  2011         5.54              22517     1929345.70
# 18     19  2012         5.55              23944     1940062.87
# 19     20  2013         5.31              24216     1901371.75
# 20     21  2014         5.25              24540     1941074.42
# 21     22  2015         5.24              25294     1859582.85
# 22     23  2016         5.18              25963     1840318.05
# 23     24  2017         5.18              26624     1920712.70
# 24     25  2018         5.36              28643     1854596.50
# 25     26  2019         5.39              29474     1836812.51
# 26     27  2020         6.10              29705     1883921.81
# 27     28  2021         5.64              31181     1897855.85
# 28     29  2022         5.73              32526     1822012.76
#
#     harvested_mill_ha  revenue_pen_2007
# 0          1972004.00           7461.75
# 1          2089580.00           7950.71
# 2          2251929.00           8730.03
# 3          2330620.00           9004.07
# 4          2480437.00           9056.08
# 5          2612304.00          10472.57
# 6          2755261.00          11488.24
# 7          2652558.48          11494.02
# 8          2699874.50          12249.73
# 9          2700584.69          12340.77
# 10         2590194.53          12292.34
# 11         2815704.46          13228.82
# 12         2869498.72          14467.84
# 13         2919240.46          14521.89
# 14         3035605.26          15935.04
# 15         3129204.79          15931.30
# 16         3113965.26          16352.56
# 17         3089042.33          17003.64
# 18         3240581.89          18476.16
# 19         3334560.86          18744.12
# 20         3266222.73          18813.99
# 21         3361676.51          19255.70
# 22         3292152.80          19606.89
# 23         3258094.72          20205.45
# 24         3439405.03          22039.95
# 25         3468402.28          22754.47
# 26         3432317.26          23399.13
# 27         3532364.32          24838.22
# 28         3564932.73          26231.07
