# %% [markdown]
# # Dataset Exploration

# %% [markdown]
# # Agriculture in Peru: The Producers
#     # People by Sector
#     # Agricultural Producers

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv(r'c:\Users\jcbur\OneDrive - peruvianbusinesscouncil.org\csv files\#9_peru_agriculture\agriculture_employment\employment_sector_gender.csv')

# Display the first few rows
print(data.head())

# Display the summary statistics
print(data.describe())

# Display the column names and types
print(data.info())
# Out:
#    index  Sum of year  region_id    region  sector_id         sector  \
# 0      1         2011        0.0  Nacional          1    Agricultura
# 1      2         2011        0.0  Nacional          1    Agricultura
# 2      3         2011        0.0  Nacional          1    Agricultura
# 3      4         2011        0.0  Nacional          2  Pesca/Minería
# 4      5         2011        0.0  Nacional          2  Pesca/Minería
#
#    gender_id   gender  Sum of value_percent
# 0          0    Total             25.206266
# 1          2  Mujeres             22.415487
# 2          1  Hombres             27.409328
# 3          0    Total              1.883800
# 4          2  Mujeres              0.293886
#              index  Sum of year    region_id   sector_id    gender_id  \
# count  7140.000000  7140.000000  7140.000000  7140.00000  7140.000000
# mean   3570.500000  2015.988235    10.528824     4.00000     1.000000
# std    2061.284794     3.159686     8.201711     2.00014     0.816554
# ...

# %% [markdown]
# # Agriculture in Peru: Main Indicators
#     # Total Revenue
#     # Agriculture contribution to the National GDP
#     # Agriculture Added Value
#     # Crops, Land Dedicated to...
#     # Harvested Land

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv(r'c:\Users\jcbur\OneDrive - peruvianbusinesscouncil.org\csv files\#9_peru_agriculture\agriculture_main_indicators\agriculture_main_indicators_may24.csv')

# Display the first few rows
print(data.head())

# Display the summary statistics
print(data.describe())

# Display the column names and types
print(data.info())
# Out:
#    index  year  gdp_percent  added_value_PEN07
# 0      1  1994         6.13              11156
# 1      2  1995         6.06              11842
# 2      3  1996         6.27              12611
# 3      4  1997         6.15              13160
# 4      5  1998         6.18              13177
#            index         year  gdp_percent  added_value_PEN07
# count  29.000000    29.000000    29.000000          29.000000
# mean   15.000000  2008.000000     5.954828       20642.344828
# std     8.514693     8.514693     0.546539        6313.033549
# min     1.000000  1994.000000     5.180000       11156.000000
# 25%     8.000000  2001.000000     5.540000       15496.000000
# 50%    15.000000  2008.000000     5.970000       20600.000000
# 75%    22.000000  2015.000000     6.270000       25294.000000
# max    29.000000  2022.000000     6.970000       32526.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 4 columns):
# ...

# %% [markdown]
# # Agriculture in Peru
#     # Natural Disasters Affecting Crops

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv(r'c:\Users\jcbur\OneDrive - peruvianbusinesscouncil.org\csv files\#9_peru_agriculture\agriculture_disasters\natural_disasters_ha_may24.csv')

# Display the first few rows
print(data.head())

# Display the summary statistics
print(data.describe())

# Display the column names and types
print(data.info())
# Out:
#    index  year  region_id    region  crops_affected_disasters
# 0      1  2003          0  Nacional                   14056.0
# 1      2  2003          1  Amazonas                      32.0
# 2      3  2003          2    Ancash                       0.0
# 3      4  2003          3  Apurimac                      40.0
# 4      5  2003          4  Arequipa                     430.0
#             index         year   region_id  crops_affected_disasters
# count  470.000000   470.000000  470.000000                470.000000
# mean   235.500000  2013.244681   12.476596               3020.528432
# std    135.821574     5.573097    7.500568              10266.862908
# min      1.000000  2003.000000    0.000000                  0.000000
# 25%    118.250000  2009.000000    6.000000                  0.000000
# 50%    235.500000  2013.000000   12.000000                 89.000000
# 75%    352.750000  2018.000000   19.000000               1433.750000
# ...

# %% [markdown]
# # Agriculture in Peru
#     # Bottomline: Socio Economic
#     # Bottomline: Access to Credit
#     # Bottomline: Access to Training

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv(r'C:\Users\jcbur\OneDrive - peruvianbusinesscouncil.org\csv files\#10_peru_producer_profile\final_assignment\producer_profile_gender_gap_2012.csv')

# Display the first few rows
print(data.head())

# Display the summary statistics
print(data.describe())

# Display the column names and types
print(data.info())
# Out:
#    index  region_id    region  gender_id gender  producers_thousands  \
# 0      1          0  Nacional          1    men             1554.781
# 1      2          1  Amazonas          1    men               56.037
# 2      3          2    Ancash          1    men              109.358
# 3      4          3  Apurimac          1    men               56.581
# 4      5          4  Arequipa          1    men               37.845
#
#    granted_loans_thousands  illiteracy_percent  postgraduate_percent  \
# 0                  145.989            8.884209              7.475265
# 1                    3.880            5.601656              6.085265
# 2                    4.014           11.872017              6.085265
# 3                    6.755           13.683038              7.723441
# 4                    7.400            3.065134             20.068701
#
#    primary_percent  ...    spanish    quechua    aymara   amazonia  \
# ...
