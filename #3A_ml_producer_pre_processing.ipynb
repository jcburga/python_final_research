# %% [markdown]
# # Import Pandas and Select Tools

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.impute import SimpleImputer

# %% [markdown]
# # Pre - Processing

# %% [markdown]
#     - Selecting Preprocessing Tools

# %%
# Load the dataset
df = pd.read_csv(r'C:\Users\jcbur\OneDrive - peruvianbusinesscouncil.org\csv files\#11_python_final_assignment\#6_statystical_ratios\ml_producer_profile_selected_features.csv')

# Specify your categorical and numerical columns
categorical_columns = ['category_region_id']
numerical_columns = ['producers_numerical', 'granted_loans_percent', 'requested_loans_percent', 'trained_percent', 'employment_agriculture_percent', 'illiteracy_percent', 'education_primary_completed_percent', 'education_secondary_completed_percent', 'belongs_producers_association_percent', 'language_spanish_percent', 'language_quechua_percent', 'language_aymara_percent', 'language_amazonia_percent']

# Step 3: Handle missing values
imputer = SimpleImputer(strategy='most_frequent') # for categorical columns
df[categorical_columns] = imputer.fit_transform(df[categorical_columns])
imputer = SimpleImputer(strategy='mean') # for numerical columns
df[numerical_columns] = imputer.fit_transform(df[numerical_columns])

# Step 4: Encode categorical variables
encoder = LabelEncoder()
df[categorical_columns] = df[categorical_columns].apply(encoder.fit_transform)

# Step 5: Scale numerical variables
scaler = StandardScaler()
df[numerical_columns] = scaler.fit_transform(df[numerical_columns])

# Print the preprocessed data
print(df)
# Out:
#     category_region_id  producers_numerical  granted_loans_percent  \
# 0                    0            -4.844443              -0.016926
# 1                    1             0.159103               0.088910
# 2                    2             0.116970               0.695255
# 3                    3             0.235106              -0.107555
# 4                    4             0.312079              -1.640356
# 5                    5             0.228295               0.236927
# 6                    6            -0.176348               0.391510
# 7                    7            -0.006645               0.734700
# 8                    8             0.244107               0.545425
# 9                    9             0.107505               0.352217
# 10                  10             0.366362              -2.090400
# 11                  11             0.155747              -0.770499
# 12                  12             0.096661               0.294958
# 13                  13             0.281382              -1.263180
# 14                  14             0.251394              -0.476943
# 15                  15             0.111057               1.274643
# 16                  16             0.402624               1.158122
# 17                  17             0.396582               0.571407
# 18                  18             0.325352               0.203373
# 19                  19            -0.042706              -1.573544
# 20                  20             0.156351               1.016088
# 21                  21             0.017619              -0.760962
# 22                  22             0.397107               0.755848
# 23                  23             0.386763              -1.497193
# 24                  24             0.321977               1.878176
#
#     requested_loans_percent  trained_percent  illiteracy_percent  \
# 0                 -0.048803        -0.059508            0.495824
# 1                  0.066384         0.208695            0.008639
# 2                  0.715282         0.740798            0.795494
# 3                 -0.082513        -0.234733            1.888762
# 4                 -1.598661        -1.116964           -0.559676
# 5                  0.197654        -0.693223            1.746683
# 6                  0.387299         0.333779            0.583883
# 7                  0.693965        -0.575420            1.124442
# 8                  0.517502         0.476452            1.487697
# 9                  0.222958         0.503709            0.820264
# 10                -2.064528        -2.219639           -1.462266
# 11                -0.957135        -1.077510           -0.594238
# 12                 0.350700         0.651913            0.585595
# 13                -1.250519        -0.434029           -0.040230
# 14                -0.483734        -0.597522           -1.119225
# 15                 1.304692         1.854098           -0.391362
# 16                 1.326622         1.774971           -1.282182
# 17                 0.564968        -0.016876           -0.664141
# 18                 0.155407         0.405742           -0.046380
# 19                -1.510971        -1.119799            0.492294
# 20                 1.010022         0.696985            0.697653
# 21                -0.834736        -0.096741           -0.759705
# 22                 0.763401        -1.468071           -0.974561
# 23                -1.348915         0.068595           -1.639938
# 24                 1.903657         1.994300           -1.193325
#
#     education_primary_completed_percent  \
# 0                             -0.040533
# 1                             -0.246428
# 2                              0.421877
# 3                              1.433614
# 4                              0.556947
# 5                              1.790990
# 6                             -0.567070
# 7                              0.352433
# 8                              1.295273
# 9                             -0.443415
# 10                            -0.059632
# 11                            -0.242710
# 12                            -1.005795
# 13                             1.220808
# 14                             0.315490
# 15                            -0.413253
# 16                            -1.392281
# 17                            -0.428030
# 18                            -0.370212
# 19                            -0.746661
# 20                             1.875178
# 21                            -2.066142
# 22                             0.975485
# 23                            -0.999623
# 24                            -1.216307
#
#     education_secondary_completed_percent  \
# 0                                0.135999
# 1                                0.046100
# 2                                0.016883
# 3                               -1.328331
# 4                               -1.836343
# 5                               -1.836343
# 6                                0.804236
# 7                               -0.396262
# 8                               -1.707737
# 9                                0.602183
# 10                               0.760141
# 11                               0.009486
# 12                               1.088945
# 13                              -1.007507
# 14                              -0.393147
# 15                               0.481006
# 16                               0.941891
# 17                               0.617749
# 18                               0.047746
# 19                               0.699840
# 20                              -1.296619
# 21                               1.890946
# 22                              -0.272099
# 23                               0.600787
# 24                               1.330450
#
#     belongs_producers_association_percent  language_spanish_percent  \
# 0                               -0.033684                 -1.424149
# 1                                0.212541                 -0.812809
# 2                               -1.978633                 -2.055934
# 3                               -0.955903                 -0.566485
# 4                                0.562499                 -0.561950
# 5                                1.551744                 -0.642701
# 6                               -0.921070                  0.051404
# 7                                0.950125                  0.214813
# 8                                0.219052                  0.337130
# 9                               -0.382187                 -1.178125
# 10                               0.183035                  0.505169
# 11                               2.013716                  2.462914
# 12                              -1.440875                  0.077113
# 13                               2.081326                  1.029230
# 14                              -0.162207                 -0.052003
# 15                               0.257910                 -0.734511
# 16                              -0.280729                  1.619442
# 17                               0.410252                  0.494430
# 18                               0.495018                  0.096993
# 19                              -0.500244                  0.054177
# 20                              -0.343526                 -0.380363
# 21                              -0.825509                 -0.447568
# 22                              -1.098118                 -0.219577
# 23                              -1.036394                  0.064862
# 24                               1.021862                  2.068496
#
#     language_quechua_percent  language_aymara_percent  \
# 0                   1.548435                 2.357520
# 1                  -0.271513                -0.091944
# 2                   2.520301                -0.092930
# 3                   0.582915                -0.099666
# 4                   0.740114                -0.739275
# 5                   0.680188                -0.059649
# 6                  -0.240437                -0.089639
# 7                  -0.198426                -0.089639
# 8                  -0.611545                -0.074024
# 9                   1.421013                -0.100961
# 10                 -0.776096                -0.120923
# 11                 -1.659793                -0.143619
# 12                 -0.273183                -0.076257
# 13                 -1.530197                -0.101812
# 14                 -0.128178                -0.021358
# 15                 -0.033453                -0.082082
# 16                 -1.469088                 0.223013
# 17                 -1.392197                 2.175456
# 18                  0.892278                -0.079133
# 19                 -0.252176                -0.088523
# 20                  1.199103                -3.540381
# 21                 -0.137206                -0.082875
# 22                 -0.199209                 1.192445
# 23                 -0.268511                -0.087604
# 24                 -0.143140                -0.086139
#
#     language_amazonia_percent  employment_agriculture_percent
# 0                   -0.363825                        0.303695
# 1                    1.790996                       -1.063696
# 2                    0.259126                        0.533724
# 3                    0.242872                       -0.345713
# 4                    0.240121                        0.946334
# 5                    0.233001                        0.333344
# 6                    0.257748                       -0.155797
# 7                   -0.079623                        0.882625
# 8                    0.248301                        0.879110
# 9                    0.194890                       -0.357756
# 10                   0.190603                        0.663516
# 11                  -2.016637                        0.189546
# 12                   0.252075                       -0.007757
# 13                   0.273176                        0.703676
# 14                   0.265688                        0.909485
# 15                   1.338989                       -0.662732
# 16                  -0.933715                       -1.048629
# 17                   0.259036                        0.797552
# 18                  -1.316569                       -0.017858
# 19                   0.268055                       -1.952876
# 20                   0.251206                        1.866342
# 21                   0.980692                       -2.722130
# 22                   0.245860                        0.879540
# 23                   0.270828                       -0.782072
# 24                  -3.352892                       -0.771472
